# %% [markdown]
# # Initial Pipeline
# **Goal:** Implement a data processing pipeline using appropriate data structures for different operations on contract financial data.
#
# **Tasks:**
# 1. Create a basic pipeline script that:
#    - Loads contract transaction data using naive approach (loading all at once)
#    - Processes vendor and project data using basic data structures
#    - Implements simple financial analysis functions (spend by category, budget variance)
#
# 2. Implement specific components with appropriate data structures:
#    - **Contract Lookup:** Dictionary-based contract catalog with O(1) access by contract ID
#    - **Transaction Processing:** List-based storage with sequential processing for financial transactions
#    - **Vendor Analysis:** Set-based unique vendor grouping for spend analysis
#    - **Timeline Tracking:** Queue-based transaction sequence for chronological analysis
#
# 3. Document each data structure choice with justification and complexity analysis
#
# **Deliverable:** A functioning but unoptimized pipeline (`initial_financial_pipeline.py`)
#
# ## Exploratory Data Analysis
# Let's look at the incoming data structure.
#
# ### Contracts

# %%
import pandas as pd
import os

DATA_PATH = '../data/raw/'

# Import contracts data
con_df = pd.read_csv(os.path.join(DATA_PATH, 'contracts.csv'))
con_df.head()
# Out:
#   contract_id     contract_number vendor_id project_id  \
# 0  CTR-000001  N0027132-53-D-2254  VEN-0132   PRJ-0047
# 1  CTR-000002  N0041190-61-D-4930  VEN-0084   PRJ-0027
# 2  CTR-000003  N0092555-85-D-1451  VEN-0190   PRJ-0016
# 3  CTR-000004  N0097012-45-D-2287  VEN-0061   PRJ-0001
# 4  CTR-000005  N0079544-11-D-7162  VEN-0101   PRJ-0002
#
#              contract_type  start_date    end_date  original_value  \
# 0  Cost-Plus-Incentive-Fee  2024-01-07  2025-01-06     20837173.33
# 1       Time-and-Materials  2023-07-13  2025-07-12     19545536.60
# 2         Firm-Fixed-Price  2023-05-31  2024-05-30     46294987.63
# 3       Time-and-Materials  2022-09-20  2025-09-19     40540302.76
# 4         Firm-Fixed-Price  2021-01-13  2024-01-13     23498686.99
#
#    current_value  status   department  \
# 0    18753456.00  Active  Coast Guard
# 1    19545536.60  Active      Marines
# 2    46294987.63  Active          NSA
# 3    60810454.14  Active        DARPA
# 4    23498686.99  Active         Army
#
#                                description contracting_officer
# 0                   exploit killer markets           PER-00528
# 1             orchestrate turn-key schemas           PER-00491
# 2     architect innovative functionalities           PER-00286
# 3         repurpose impactful web services           PER-00380
# 4  maximize bricks-and-clicks web services           PER-00641

# %%
con_df.describe(include='all')
# Out:
#        contract_id     contract_number vendor_id project_id  \
# count          500                 500       500        500
# unique         500                 500       187         50
# top     CTR-000001  N0027132-53-D-2254  VEN-0004   PRJ-0044
# freq             1                   1         8         18
# mean           NaN                 NaN       NaN        NaN
# std            NaN                 NaN       NaN        NaN
# min            NaN                 NaN       NaN        NaN
# 25%            NaN                 NaN       NaN        NaN
# 50%            NaN                 NaN       NaN        NaN
# 75%            NaN                 NaN       NaN        NaN
# max            NaN                 NaN       NaN        NaN
#
#               contract_type  start_date    end_date  original_value  \
# count                   500         500         500    5.000000e+02
# unique                    6         442         461             NaN
# top     Cost-Plus-Award-Fee  2024-03-17  2025-08-14             NaN
# freq                     96           3           3             NaN
# mean                    NaN         NaN         NaN    2.587793e+07
# std                     NaN         NaN         NaN    1.435545e+07
# min                     NaN         NaN         NaN    1.015916e+05
# 25%                     NaN         NaN         NaN    1.355133e+07
# 50%                     NaN         NaN         NaN    2.616785e+07
# 75%                     NaN         NaN         NaN    3.876231e+07
# max                     NaN         NaN         NaN    4.994804e+07
#
#         current_value  status department                         description  \
# count    5.000000e+02     500        500                                 500
# unique            NaN       5          9                                 498
# top               NaN  Active        NSA  transition clicks-and-mortar users
# freq              NaN     304         64                                   2
# mean     2.633028e+07     NaN        NaN                                 NaN
# std      1.501235e+07     NaN        NaN                                 NaN
# min      1.117508e+05     NaN        NaN                                 NaN
# 25%      1.321979e+07     NaN        NaN                                 NaN
# 50%      2.603120e+07     NaN        NaN                                 NaN
# 75%      3.920406e+07     NaN        NaN                                 NaN
# max      6.821479e+07     NaN        NaN                                 NaN
#
#        contracting_officer
# count                  500
# unique                 392
# top              PER-00292
# freq                     4
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
con_df.isna().sum()
# Out:
# contract_id            0
# contract_number        0
# vendor_id              0
# project_id             0
# contract_type          0
# start_date             0
# end_date               0
# original_value         0
# current_value          0
# status                 0
# department             0
# description            0
# contracting_officer    0
# dtype: int64

# %%
contract_dict = {con_df['contract']: contract for contracts in contract}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 contract_dict = {con_df['contract']: contract for contracts in contract}
#
# NameError: name 'contract' is not defined

# %% [markdown]
# ### Personnel

# %%
pers_df = pd.read_csv(os.path.join(DATA_PATH, 'personnel.csv'))
pers_df.head()
# Out:
#   personnel_id            name                   role department  \
# 0    PER-00001  Rodney Freeman      Financial Analyst        DLA
# 1    PER-00002    Joseph Perez      Financial Analyst      DARPA
# 2    PER-00003  Brenda Hammond    Contract Specialist        DIA
# 3    PER-00004    James Vargas      Financial Analyst       Army
# 4    PER-00005   Robert Lester  Subject Matter Expert      DARPA
#
#                          email                  phone security_clearance  \
# 0          molly37@example.com  +1-627-733-0090x74528       Confidential
# 1   monroejonathan@example.net      780-443-3140x9757         Top Secret
# 2         proberts@example.com             3778604660       Public Trust
# 3  gonzalesgabriel@example.net        +1-260-556-9370       Confidential
# 4        ruizmisty@example.com   +1-679-403-4574x4062       Confidential
#
#     hire_date supervisor
# 0  2020-10-23  PER-00987
# 1  2006-10-31  PER-00235
# 2  2013-03-24  PER-00134
# 3  2017-03-21  PER-00355
# 4  2018-02-03  PER-00244

# %%
pers_df.describe(include='all')
# Out:
#        personnel_id          name               role   department  \
# count          1000          1000               1000         1000
# unique         1000           994                  8            9
# top       PER-00001  Crystal Reed  Quality Assurance  Coast Guard
# freq              1             2                141          120
#
#                     email                  phone security_clearance  \
# count                1000                   1000               1000
# unique                997                   1000                  5
# top     hcole@example.net  +1-627-733-0090x74528         Top Secret
# freq                    2                      1                227
#
#          hire_date supervisor
# count         1000        796
# unique         939        548
# top     2011-06-24  PER-00538
# freq             3          5

# %% [markdown]
# ### Projects

# %%
proj_df = pd.read_csv(os.path.join(DATA_PATH, 'projects.csv'))
proj_df.head()
# Out:
#   project_id                                        name          type  \
# 0   PRJ-0001         Project Synergistic national access  Construction
# 1   PRJ-0002  Project Public-key multimedia service-desk      Research
# 2   PRJ-0003   Project Universal client-server hierarchy    Consulting
# 3   PRJ-0004   Project Visionary web-enabled parallelism  Construction
# 4   PRJ-0005  Project Mandatory even-keeled service-desk      Research
#
#                                          description  start_date    end_date  \
# 0  Simply live others system. Threat painting eve...  2015-10-13  2018-10-12
# 1  Current someone market government. Third train...  2017-04-15  2020-04-14
# 2  Admit ever community develop. Structure up ano...  2017-03-23  2021-03-22
# 3  Answer white now religious stuff. Sort across ...  2022-01-13  2028-01-12
# 4  Serious never cost information rather. Late hi...  2018-01-31  2025-01-29
#
#    total_budget   department program_manager priority
# 0  4.655491e+08          DIA       PER-00454   Medium
# 1  4.657074e+08          DIA       PER-00871      Low
# 2  5.260635e+06          DIA       PER-00198     High
# 3  2.205551e+08          DIA       PER-00625   Medium
# 4  4.205880e+08  Coast Guard       PER-00653     High

# %%
proj_df.describe(include='all')
# Out:
#        project_id                                 name         type  \
# count          50                                   50           50
# unique         50                                   50           10
# top      PRJ-0001  Project Synergistic national access  Development
# freq            1                                    1            8
# mean          NaN                                  NaN          NaN
# std           NaN                                  NaN          NaN
# min           NaN                                  NaN          NaN
# 25%           NaN                                  NaN          NaN
# 50%           NaN                                  NaN          NaN
# 75%           NaN                                  NaN          NaN
# max           NaN                                  NaN          NaN
#
#                                               description  start_date  \
# count                                                  50          50
# unique                                                 50          49
# top     Simply live others system. Threat painting eve...  2015-10-13
# freq                                                    1           2
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#           end_date  total_budget department program_manager priority
# count           50  5.000000e+01         50              50       50
# unique          49           NaN          9              46        4
# top     2019-10-12           NaN        NSA       PER-00081      Low
# freq             2           NaN          9               2       18
# mean           NaN  2.562121e+08        NaN             NaN      NaN
# std            NaN  1.597913e+08        NaN             NaN      NaN
# min            NaN  5.260635e+06        NaN             NaN      NaN
# 25%            NaN  1.017770e+08        NaN             NaN      NaN
# 50%            NaN  2.551375e+08        NaN             NaN      NaN
# 75%            NaN  4.174940e+08        NaN             NaN      NaN
# max            NaN  4.999287e+08        NaN             NaN      NaN

# %% [markdown]
# ### Deliverables

# %%
deliv_df = pd.read_csv(os.path.join(DATA_PATH,'deliverables.csv'))
deliv_df.head()
# Out:
#   deliverable_id contract_id  \
# 0     DEL-000001  CTR-000453
# 1     DEL-000002  CTR-000397
# 2     DEL-000003  CTR-000095
# 3     DEL-000004  CTR-000291
# 4     DEL-000005  CTR-000314
#
#                                               title           type  \
# 0        Deliverable harness plug-and-play channels       Training
# 1      Deliverable facilitate efficient convergence  Documentation
# 2            Deliverable drive rich functionalities      Prototype
# 3      Deliverable deploy integrated info-mediaries       Hardware
# 4  Deliverable facilitate interactive web-readiness           Data
#
#      due_date delivery_date     status  \
# 0  2024-07-15    2024-07-15  Delivered
# 1  2024-03-08    2024-03-11   Accepted
# 2  2022-01-30           NaN    Pending
# 3  2020-01-12    2020-01-12  Delivered
# 4  2026-04-25    2026-05-02   Accepted
#
#                                          description accepted   reviewer
# 0  Allow especially outside return stage full pre...      Yes  PER-00549
# 1  Black cover company somebody become fish appro...      NaN  PER-00423
# 2                             Sense expect stuff up.      NaN  PER-00136
# 3           Lose lay plan hundred necessary in wide.      Yes  PER-00292
# 4         Ever avoid responsibility both as develop.      NaN  PER-00254

# %%
deliv_df.describe(include='all')
# Out:
#        deliverable_id contract_id  \
# count            5000        5000
# unique           5000         500
# top        DEL-000001  CTR-000343
# freq                1          20
#
#                                                title           type  \
# count                                           5000           5000
# unique                                          4914              7
# top     Deliverable redefine open-source convergence  Documentation
# freq                                               2            780
#
#           due_date delivery_date   status  \
# count         5000          3020     5000
# unique        2210          1701        5
# top     2024-11-23    2025-06-12  Pending
# freq            11             7     1038
#
#                                               description accepted   reviewer
# count                                                5000     1019       5000
# unique                                               5000        3        993
# top     Allow especially outside return stage full pre...      Yes  PER-00564
# freq                                                    1      801         15

# %% [markdown]
# ### Contract Modifications

# %%
# Load the contract modifications data
con_mod_df = pd.read_csv(os.path.join(DATA_PATH,"contract_modifications.csv"))
con_mod_df.head()
# Out:
#   modification_id contract_id mod_number    mod_date            type  \
# 0      MOD-000001  CTR-000183       P199  2024-06-21         Funding
# 1      MOD-000002  CTR-000377       P972  2027-08-21        Schedule
# 2      MOD-000003  CTR-000221       P750  2024-08-07  Administrative
# 3      MOD-000004  CTR-000078       P313  2022-07-27     Termination
# 4      MOD-000005  CTR-000337       P113  2023-12-20     Termination
#
#                                          description  value_change  \
# 0                          Stuff through guy member.    4390464.09
# 1          Staff same serious visit past time admit.          0.00
# 2  Understand from age receive ready particularly...          0.00
# 3  Position resource direction experience north r...          0.00
# 4   Society despite sense write doctor article they.          0.00
#
#    days_change approved_by    status
# 0            0   PER-00718  Rejected
# 1           83   PER-00066  Approved
# 2            0   PER-00615  Approved
# 3            0   PER-00376  Rejected
# 4            0   PER-00463   Pending

# %%
con_mod_df.describe(include='all')
# Out:
#        modification_id contract_id mod_number    mod_date       type  \
# count             2000        2000       2000        2000       2000
# unique            2000         492        799        1370          6
# top         MOD-000001  CTR-000097       P248  2025-05-01  Extension
# freq                 1          10          9           7        379
# mean               NaN         NaN        NaN         NaN        NaN
# std                NaN         NaN        NaN         NaN        NaN
# min                NaN         NaN        NaN         NaN        NaN
# 25%                NaN         NaN        NaN         NaN        NaN
# 50%                NaN         NaN        NaN         NaN        NaN
# 75%                NaN         NaN        NaN         NaN        NaN
# max                NaN         NaN        NaN         NaN        NaN
#
#                       description  value_change  days_change approved_by  \
# count                        2000  2.000000e+03  2000.000000        2000
# unique                       2000           NaN          NaN         889
# top     Stuff through guy member.           NaN          NaN   PER-00115
# freq                            1           NaN          NaN           8
# mean                          NaN  7.449318e+05    25.520500         NaN
# std                           NaN  3.468195e+06    49.920854         NaN
# min                           NaN -1.038482e+07   -30.000000         NaN
# 25%                           NaN  0.000000e+00     0.000000         NaN
# 50%                           NaN  0.000000e+00     0.000000         NaN
# 75%                           NaN  8.382131e+05    28.000000         NaN
# max                           NaN  1.627860e+07   180.000000         NaN
#
#          status
# count      2000
# unique        4
# top     Pending
# freq        529
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN
